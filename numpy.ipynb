# %%
import numpy as np

# %%
l1=[100,200,300,400,500]
y=[x+50 for x in l1]
y
# Out:
# [150, 250, 350, 450, 550]

# %%
a1=np.array(l1)
print(a1)
type(a1)
# Out:
# [100 200 300 400 500]
# numpy.ndarray

# %%
l2=[10,3.5,'np',9+3j]
np.array(l2)
# Out:
# array(['10', '3.5', 'np', '(9+3j)'], dtype='<U64')

# %%
l1=[100,200,300,400,500]
l2=[10,3.5,'np',9+3j]
print(l1+l2)
# Out:
# [100, 200, 300, 400, 500, 10, 3.5, 'np', (9+3j)]

# %%
l1=[100,200,300,400,500]
l2=[10,20,30,40,50]
arr1=np.array(l1)
arr2=np.array(l2)
print(arr1+arr2)
# Out:
# [110 220 330 440 550]

# %%
arr3=np.array([10,2,5,60,40,80,8,4])
arr3
# Out:
# array([10,  2,  5, 60, 40, 80,  8,  4])

# %%
# print(arr2+arr3) #Should of same size
'''ValueError: operands could not be broadcast together with shapes (5,) (8,)'''
# Out:
# 'ValueError: operands could not be broadcast together with shapes (5,) (8,)'

# %%
arr4=np.array([[10,20],[30,40],[50,60]])

# %%
# print(arr1+arr4) #should be of same dimensional
'''ValueError: operands could not be broadcast together with shapes (5,) (3,2)'''
# Out:
# 'ValueError: operands could not be broadcast together with shapes (5,) (3,2)'

# %%
'''To check the dimension of array'''
arr4.ndim
# Out:
# 2

# %%
'''To check number of rows and columns'''
arr4.shape
# Out:
# (3, 2)

# %%
'''To check the size of the array'''
arr4.size
# Out:
# 6

# %%
'''To check each item size in bytes'''
arr4.itemsize
# Out:
# 4

# %%
'''To check the total number of bytes for the array'''
arr4.nbytes
# Out:
# 24
