# %%
import numpy as np

# %%
a1=np.array([10,20,30,])
print(a1)
# Out:
# [10 20 30]

# %% [markdown]
# - power( ) function
# - for each element in the array it will multiply the value itself, based on the power value given

# %%
np.power(a1,2)
# Out:
# array([100, 400, 900], dtype=int32)

# %% [markdown]
# - sum( ) function
# - sum( ) will add all the elements in the array

# %%
np.sum(a1)
# Out:
# 60

# %% [markdown]
# - std( ) function gives the standard deviation of the array passed

# %%
np.std(a1)
# Out:
# 8.16496580927726

# %% [markdown]
# - mean( ) gives the average value of given array

# %%
np.mean(a1)
# Out:
# 20.0

# %% [markdown]
# - var( ) function
# - used to check the how far the value is from the mean value
# - if variance value is less, near to the mean value
# - if variance value is high, far from the mean value

# %%
np.var(a1)
# Out:
# 66.66666666666667

# %%
a2=np.array([1,0,2])
print(a2)
# Out:
# [1 0 2]

# %% [markdown]
# - exp( ) function
# - gives the power value

# %%
np.exp(a2)
# Out:
# array([2.71828183, 1.        , 7.3890561 ])

# %% [markdown]
# - log( ) functions
# - gives the value of that power

# %%
a3=np.array([2.71828183, 1.        , 7.3890561 ])
np.log(a3)
# Out:
# array([1., 0., 2.])

# %% [markdown]
# - isin ( ) - it works like a membership operator to check wheather the element is present in the array or not

# %%
arr1=np.array([10,2,15,5,9,20])
print(arr1)
# Out:
# [10  2 15  5  9 20]

# %%
20 in arr1
# Out:
# True

# %%
np.isin(20,arr1)
# Out:
# array(True)

# %%
np.isin([20,5,15,666],arr1)
# Out:
# array([ True,  True,  True, False])

# %% [markdown]
# - sort( ) - bydefault arranges in ascending order

# %%
np.sort(arr1)
# Out:
# array([ 2,  5,  9, 10, 15, 20])

# %% [markdown]
# - median( ) - return the mid value

# %%
np.median(arr1)
# Out:
# 9.5

# %%
np.percentile(arr1,25)
# Out:
# 6.0

# %%
np.percentile(arr1,50)
# Out:
# 9.5

# %%
np.percentile(arr1,75)
# Out:
# 13.75

# %%
np.percentile(arr1,100)
# Out:
# 20.0

# %% [markdown]
# - where( ), it returns the values in the array which are in the given range of value passed in the where function condition

# %%
arr1[np.where(arr1<11)]
# Out:
# array([10,  2,  5,  9])
