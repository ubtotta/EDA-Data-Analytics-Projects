# %%
import numpy as np

# %%
a1=np.array([10,20,30])
print(a1)
# Out:
# [10 20 30]

# %% [markdown]
# ## shallow copy

# %%
s_a=np.copy(a1)
print(s_a)

s_a[0]=100
print(s_a)
print(a1)
# Out:
# [10 20 30]
# [100  20  30]
# [10 20 30]
