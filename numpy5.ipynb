# %%
import numpy as np

# %% [markdown]
# ## Broadcasting of arrays
# - array rules

# %%
l1=[10,20,30]
a1=np.array(l1)
print(a1)
a1.shape
# Out:
# [10 20 30]
# (3,)

# %%
l2=[40,50,60,70]
a2=np.array(l2)
print(a2)
a2.shape
# Out:
# [40 50 60 70]
# (4,)

# %%
# a1+a2
# ValueError: operands could not be broadcast together with shapes (3,) (4,)
